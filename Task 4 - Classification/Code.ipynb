# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder,StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay,classification_report

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is A09C-8A30
#
#  Directory of C:\Users\Ahmed-Basem\Desktop\Current\Corelia\Task 4
#
# 05/09/2023  05:30 PM    <DIR>          .
# 05/09/2023  05:30 PM    <DIR>          ..
# 05/09/2023  04:23 PM    <DIR>          .ipynb_checkpoints
# 05/23/2022  07:24 PM            32,218 cc_approvals.data
# 05/09/2023  05:30 PM         1,118,332 Code.ipynb
# 05/23/2022  07:24 PM               186 Columns.txt
#                3 File(s)      1,150,736 bytes
#                3 Dir(s)  20,249,174,016 bytes free

# %%
with open('Columns.txt') as f:
    lines = f.readlines()

# %%
lines = [line.strip() for line in lines]
lines
# Out:
# ['Gender',
#  'Age',
#  'Debt',
#  'Married',
#  'BankCustomer',
#  'EducationLevel',
#  'Ethnicity',
#  'YearsEmployed',
#  'PriorDefault',
#  'Employed',
#  'CreditScore',
#  'DriversLicense',
#  'Citizen',
#  'ZipCode',
#  'Income',
#  'Approved']

# %%
data = pd.read_csv('cc_approvals.data',names=lines)
data.head()
# Out:
#   Gender    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      b  30.83  0.000       u            g              w         v
# 1      a  58.67  4.460       u            g              q         h
# 2      a  24.50  0.500       u            g              q         h
# 3      b  27.83  1.540       u            g              w         v
# 4      b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved
# 0   00202       0        +
# 1   00043     560        +
# 2   00280     824        +
# 3   00100       3        +
# 4   00120       0        +

# %%
print(f"There are {data.shape[0]} Rows and data {data.shape[1]} Column")
# Out:
# There are 690 Rows and data 16 Column

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 690 entries, 0 to 689
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Gender          690 non-null    object
#  1   Age             690 non-null    object
#  2   Debt            690 non-null    float64
#  3   Married         690 non-null    object
#  4   BankCustomer    690 non-null    object
#  5   EducationLevel  690 non-null    object
#  6   Ethnicity       690 non-null    object
#  7   YearsEmployed   690 non-null    float64
#  8   PriorDefault    690 non-null    object
#  9   Employed        690 non-null    object
#  10  CreditScore     690 non-null    int64
#  11  DriversLicense  690 non-null    object
#  12  Citizen         690 non-null    object
#  13  ZipCode         690 non-null    object
#  14  Income          690 non-null    int64
#  15  Approved        690 non-null    object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 86.4+ KB

# %%
data.isnull().sum()
# Out:
# Gender            0
# Age               0
# Debt              0
# Married           0
# BankCustomer      0
# EducationLevel    0
# Ethnicity         0
# YearsEmployed     0
# PriorDefault      0
# Employed          0
# CreditScore       0
# DriversLicense    0
# Citizen           0
# ZipCode           0
# Income            0
# Approved          0
# dtype: int64

# %%
def get_insights(col):
    print(f"#### {col} and its data type is *{data[col].dtype}* \n")
    print("Number of ? values",data[col].tolist().count("?"))
    print("\nnumber of unique values",data[col].nunique())
    print(f"\n#### Top 5 values ####")
    print(data[col].value_counts().index.values[:5])
    print(f'\n#### Random Values ####')
    print(data[col].sample(5).values)
    
def count_plot(col,title):
    plt.figure(figsize=(10,6))
    sns.countplot(data=data,x=col)
    plt.xticks(rotation=30)
    plt.title(title)
    plt.show()
def multi_count_plot(col,col2):
    plt.figure(figsize=(10,6))
    sns.countplot(data=data,x=col,hue=col2)
    plt.xticks(rotation=45)
    plt.show()
def pie_plot(col,limit=10,title=''):
    plt.figure(figsize=(10,6))
    plt.pie(x=data[col].value_counts()[:limit],labels=data[col].value_counts()[:limit].index,
           autopct='%1.1f%%')
    plt.title(title)
    plt.show()
def kde_plot(col):
    plt.figure(figsize=(10,6))
    sns.kdeplot(data=data[col],shade=True)
    plt.show()
def scatter_plot(col1,col2,title):
    plt.figure(figsize=(10,6))
    plt.scatter(data[col1], data[col2])
    plt.title(title)
    plt.xlabel(col1)
    plt.ylabel(col2)
    plt.show()
def barplot_mean(col,title):
    plt.figure(figsize=(10,6))
    sns.barplot(x=data.groupby('Approved')[col].mean().index,
                y=data.groupby('Approved')[col].mean().values)
    plt.title(title)
    plt.show()
def approved_vs_not(col,Limit=5):
    fig,ax = plt.subplots(figsize=(15,4))
    plt.subplot(1,2,1)
    plt.title('Approved')
    positive = data[data['Approved']=='+']
    plt.pie(positive[col].value_counts()[:Limit],labels=
        positive[col].value_counts()[:Limit].index,
           autopct='%1.1f%%')
    plt.subplot(1,2,2)
    plt.title('Not Approved')
    negative = data[data['Approved']=='-']
    plt.pie(negative[col].value_counts()[:Limit],labels=
        negative[col].value_counts()[:Limit].index,
        autopct ='%1.2f%%' )
    plt.show()

# %%
get_insights('Gender')
# Out:
# #### Gender and its data type is *object*
#
# Number of ? values 12
#
# number of unique values 3
#
# #### Top 5 values ####
# ['b' 'a' '?']
#
# #### Random Values ####
# ['b' 'a' 'b' 'b' 'a']

# %%
for col in data.columns:
    count = data[col].tolist().count('?')
    if count > 0 :
        print("Column:" , col)
        print(count)
# Out:
# Column: Gender
# 12
# Column: Age
# 12
# Column: Married
# 6
# Column: BankCustomer
# 6
# Column: EducationLevel
# 9
# Column: Ethnicity
# 9
# Column: ZipCode
# 13

# %%
data = data[data['Gender'] != '?']

# %%
pie_plot('Gender',title="The percentage of each Gender")

# %%
approved_vs_not('Gender')

# %%
get_insights('Age')
# Out:
# #### Age and its data type is *object*
#
# Number of ? values 12
#
# number of unique values 346
#
# #### Top 5 values ####
# ['?' '22.67' '20.67' '22.50' '23.58']
#
# #### Random Values ####
# ['27.83' '34.17' '30.83' '18.08' '22.67']

# %%
# let's replace missing of values of age with median
data.loc[data.Age == "?",'Age'] =  data[data['Age'] != "?"]['Age'].median()

# %%
data['Age'] = data['Age'].astype(float)

# %%
kde_plot('Age')

# %%
data['Age'].describe()
# Out:
# count    678.000000
# mean      31.520605
# std       11.919352
# min       13.750000
# 25%       22.670000
# 50%       28.375000
# 75%       37.707500
# max       80.250000
# Name: Age, dtype: float64

# %%
barplot_mean('Age','The mean of Age vs Approved')

# %% [markdown]
# ### Debt

# %%
get_insights('Debt')
# Out:
# #### Debt and its data type is *float64*
#
# Number of ? values 0
#
# number of unique values 215
#
# #### Top 5 values ####
# [1.5  2.5  3.   0.   0.75]
#
# #### Random Values ####
# [0.165 4.125 5.    6.625 0.29 ]

# %%
kde_plot('Debt')

# %%
get_insights('Married')
# Out:
# #### Married and its data type is *object*
#
# Number of ? values 6
#
# number of unique values 4
#
# #### Top 5 values ####
# ['u' 'y' '?' 'l']
#
# #### Random Values ####
# ['u' 'u' 'u' 'u' 'u']

# %%
data.loc[data.Married == "?",:]
# Out:
#     Gender    Age  Debt Married BankCustomer EducationLevel Ethnicity  \
# 206      a  71.58   0.0       ?            ?              ?         ?
# 270      b  37.58   0.0       ?            ?              ?         ?
# 330      b  20.42   0.0       ?            ?              ?         ?
# 456      b  34.58   0.0       ?            ?              ?         ?
# 592      b  23.17   0.0       ?            ?              ?         ?
# 622      a  25.58   0.0       ?            ?              ?         ?
#
#      YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 206            0.0            f        f            0              f       p
# 270            0.0            f        f            0              f       p
# 330            0.0            f        f            0              f       p
# 456            0.0            f        f            0              f       p
# 592            0.0            f        f            0              f       p
# 622            0.0            f        f            0              f       p
#
#     ZipCode  Income Approved
# 206       ?       0        +
# 270       ?       0        +
# 330       ?       0        -
# 456       ?       0        -
# 592       ?       0        +
# 622       ?       0        +

# %%
data = data.loc[data.Married != "?",:]

# %%
pie_plot('Married')

# %%
approved_vs_not('Married')

# %% [markdown]
# ### BankCustomer

# %%
get_insights('BankCustomer')
# Out:
# #### BankCustomer and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 3
#
# #### Top 5 values ####
# ['g' 'p' 'gg']
#
# #### Random Values ####
# ['g' 'g' 'p' 'g' 'p']

# %%
pie_plot('BankCustomer')

# %%
approved_vs_not('BankCustomer')

# %% [markdown]
# ### EducationLevel

# %%
get_insights('EducationLevel')
# Out:
# #### EducationLevel and its data type is *object*
#
# Number of ? values 1
#
# number of unique values 15
#
# #### Top 5 values ####
# ['c' 'q' 'w' 'i' 'aa']
#
# #### Random Values ####
# ['k' 'x' 'w' 'c' 'ff']

# %%
data = data.loc[data.EducationLevel != "?",:]

# %%
pie_plot('EducationLevel',10)

# %%
count_plot('EducationLevel','The count of education category')

# %%
multi_count_plot('EducationLevel','Approved')

# %% [markdown]
# ### Ethnicity

# %%
get_insights('Ethnicity')
# Out:
# #### Ethnicity and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 9
#
# #### Top 5 values ####
# ['v' 'h' 'bb' 'ff' 'j']
#
# #### Random Values ####
# ['v' 'h' 'v' 'v' 'ff']

# %%
pie_plot('Ethnicity')

# %%
count_plot("Ethnicity","The count of each Category")

# %%
approved_vs_not('Ethnicity')

# %% [markdown]
# ### YearsEmployed

# %%
get_insights('YearsEmployed')
# Out:
# #### YearsEmployed and its data type is *float64*
#
# Number of ? values 0
#
# number of unique values 132
#
# #### Top 5 values ####
# [0.    0.25  0.04  1.    0.125]
#
# #### Random Values ####
# [1.    8.5   0.29  1.25  0.085]

# %%
kde_plot('YearsEmployed')

# %%
barplot_mean('YearsEmployed',"The mean of YearsEmployed vs Approved")

# %% [markdown]
# ### PriorDefault

# %%
get_insights('PriorDefault')
# Out:
# #### PriorDefault and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 2
#
# #### Top 5 values ####
# ['t' 'f']
#
# #### Random Values ####
# ['t' 'f' 'f' 't' 'f']

# %%
pie_plot('PriorDefault')

# %%
approved_vs_not('PriorDefault')

# %%
data.head()
# Out:
#   Gender    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      b  30.83  0.000       u            g              w         v
# 1      a  58.67  4.460       u            g              q         h
# 2      a  24.50  0.500       u            g              q         h
# 3      b  27.83  1.540       u            g              w         v
# 4      b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#   ZipCode  Income Approved
# 0   00202       0        +
# 1   00043     560        +
# 2   00280     824        +
# 3   00100       3        +
# 4   00120       0        +

# %% [markdown]
# ### Employed

# %%
get_insights('Employed')
# Out:
# #### Employed and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 2
#
# #### Top 5 values ####
# ['f' 't']
#
# #### Random Values ####
# ['t' 't' 'f' 'f' 'f']

# %%
pie_plot('Employed')

# %%
multi_count_plot('Employed','Approved')

# %% [markdown]
# ### CreditScore

# %%
get_insights('CreditScore')
# Out:
# #### CreditScore and its data type is *int64*
#
# Number of ? values 0
#
# number of unique values 23
#
# #### Top 5 values ####
# [0 1 2 3 6]
#
# #### Random Values ####
# [2 2 0 0 0]

# %%
kde_plot('CreditScore')

# %%
barplot_mean('CreditScore',"The mean of CreditScore vs Approved")

# %% [markdown]
# ### DriversLicense

# %%
get_insights('DriversLicense')
# Out:
# #### DriversLicense and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 2
#
# #### Top 5 values ####
# ['f' 't']
#
# #### Random Values ####
# ['f' 'f' 't' 't' 't']

# %%
pie_plot('DriversLicense')

# %%
approved_vs_not('DriversLicense')

# %% [markdown]
# ### Citizen

# %%
get_insights('Citizen')
# Out:
# #### Citizen and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 3
#
# #### Top 5 values ####
# ['g' 's' 'p']
#
# #### Random Values ####
# ['g' 'g' 'g' 'g' 'g']

# %%
pie_plot('Citizen')

# %%
approved_vs_not('Citizen')

# %% [markdown]
# ### ZipCode

# %%
get_insights('ZipCode')
# Out:
# #### ZipCode and its data type is *object*
#
# Number of ? values 7
#
# number of unique values 167
#
# #### Top 5 values ####
# ['00000' '00120' '00200' '00160' '00100']
#
# #### Random Values ####
# ['00000' '00000' '00225' '00180' '00100']

# %%
data = data.loc[data.ZipCode != "?"]

# %%
data['ZipCode'].unique()
# Out:
# array(['00202', '00043', '00280', '00100', '00120', '00360', '00164',
#        '00080', '00180', '00052', '00128', '00260', '00000', '00320',
#        '00396', '00096', '00200', '00300', '00145', '00500', '00168',
#        '00434', '00583', '00030', '00240', '00070', '00455', '00311',
#        '00216', '00491', '00400', '00239', '00160', '00711', '00250',
#        '00520', '00515', '00420', '00980', '00443', '00140', '00094',
#        '00368', '00288', '00928', '00188', '00112', '00171', '00268',
#        '00167', '00075', '00152', '00176', '00329', '00212', '00410',
#        '00274', '00375', '00408', '00350', '00204', '00040', '00181',
#        '00399', '00440', '00093', '00060', '00395', '00393', '00021',
#        '00029', '00102', '00431', '00370', '00024', '00020', '00129',
#        '00510', '00195', '00144', '00380', '00049', '00050', '00381',
#        '00150', '00117', '00056', '00211', '00230', '00156', '00022',
#        '00228', '00519', '00253', '00487', '00220', '00088', '00121',
#        '00470', '00136', '00132', '00292', '00154', '00272', '00340',
#        '00108', '00720', '00450', '00232', '00170', '00411', '00460',
#        '00348', '00480', '00640', '00276', '00221', '00352', '00141',
#        '00178', '00600', '00550', '00073', '02000', '00225', '00210',
#        '00110', '00356', '00045', '00062', '00092', '00174', '00017',
#        '00086', '00454', '00254', '00028', '00333', '00312', '00290',
#        '00371', '00099', '00252', '00760', '00560', '00130', '00523',
#        '00680', '00163', '00208', '00383', '00330', '00422', '00840',
#        '00432', '00032', '00186', '00303', '00349', '00224', '00369',
#        '00076', '00231', '00309', '00416', '00465'], dtype=object)

# %%
data['ZipCode'].min(),data['ZipCode'].max()
# Out:
# ('00000', '02000')

# %%
zip_set = set([str(i)[:3] for i in data['ZipCode'].unique()])
zip_set = list(zip_set)
zip_set
# Out:
# ['020', '007', '000', '004', '002', '008', '009', '003', '005', '001', '006']

# %%
area_dict = {}
for i in range(len(zip_set)):
    area_dict[zip_set[i]] = f"Area {i+1}"
area_dict
# Out:
# {'020': 'Area 1',
#  '007': 'Area 2',
#  '000': 'Area 3',
#  '004': 'Area 4',
#  '002': 'Area 5',
#  '008': 'Area 6',
#  '009': 'Area 7',
#  '003': 'Area 8',
#  '005': 'Area 9',
#  '001': 'Area 10',
#  '006': 'Area 11'}

# %%
data['ZipArea'] = data['ZipCode'].apply(lambda x:area_dict[str(x)[:3]])
data = data.drop(['ZipCode'],axis=1)

# %%
data['ZipArea'].value_counts()
# Out:
# Area 3     209
# Area 10    189
# Area 5     127
# Area 8      75
# Area 4      39
# Area 9      14
# Area 2       4
# Area 11      3
# Area 7       2
# Area 1       1
# Area 6       1
# Name: ZipArea, dtype: int64

# %%
count_plot('ZipArea',"")

# %%
multi_count_plot('ZipArea',"Approved")

# %% [markdown]
# ### Income

# %%
get_insights('Income')
# Out:
# #### Income and its data type is *int64*
#
# Number of ? values 0
#
# number of unique values 232
#
# #### Top 5 values ####
# [   0    1 1000  500    2]
#
# #### Random Values ####
# [2197    0 1249    0  892]

# %%
kde_plot('Income')

# %%
data.groupby('Approved').mean()['Income']
# Out:
# Approved
# +    2003.885906
# -     189.133880
# Name: Income, dtype: float64

# %%
barplot_mean('Income',"The mean of Income vs Approved")

# %% [markdown]
# ### Approved

# %%
get_insights('Approved')
# Out:
# #### Approved and its data type is *object*
#
# Number of ? values 0
#
# number of unique values 2
#
# #### Top 5 values ####
# ['-' '+']
#
# #### Random Values ####
# ['+' '+' '-' '-' '+']

# %%
count_plot("Approved","The count of Each category")

# %%
data['Approved'] = data['Approved'].apply(lambda x:1 if x == "+" else 0)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(),cmap="YlGnBu", annot=True)
plt.show()

# %%
X = data.drop('Approved',axis=1)
Y = data['Approved'].values

# %%
X.head()
# Out:
#   Gender    Age   Debt Married BankCustomer EducationLevel Ethnicity  \
# 0      b  30.83  0.000       u            g              w         v
# 1      a  58.67  4.460       u            g              q         h
# 2      a  24.50  0.500       u            g              q         h
# 3      b  27.83  1.540       u            g              w         v
# 4      b  20.17  5.625       u            g              w         v
#
#    YearsEmployed PriorDefault Employed  CreditScore DriversLicense Citizen  \
# 0           1.25            t        t            1              f       g
# 1           3.04            t        t            6              f       g
# 2           1.50            t        f            0              f       g
# 3           3.75            t        t            5              t       g
# 4           1.71            t        f            0              f       s
#
#    Income  ZipArea
# 0       0   Area 5
# 1     560   Area 3
# 2     824   Area 5
# 3       3  Area 10
# 4       0  Area 10

# %%
numerical = [col for col in X.columns if X[col].dtype != "O"]
numerical
# Out:
# ['Age', 'Debt', 'YearsEmployed', 'CreditScore', 'Income']

# %%
categorical = [col for col in X.columns if X[col].dtype == "O"]
categorical
# Out:
# ['Gender',
#  'Married',
#  'BankCustomer',
#  'EducationLevel',
#  'Ethnicity',
#  'PriorDefault',
#  'Employed',
#  'DriversLicense',
#  'Citizen',
#  'ZipArea']

# %%
for col in categorical:
    print(col + " has : " + str(X[col].nunique()))
# Out:
# Gender has : 2
# Married has : 3
# BankCustomer has : 3
# EducationLevel has : 14
# Ethnicity has : 9
# PriorDefault has : 2
# Employed has : 2
# DriversLicense has : 2
# Citizen has : 3
# ZipArea has : 11

# %%
transform_pipeline = ColumnTransformer([
    ('num',StandardScaler(),numerical),
    ('category',OneHotEncoder(),categorical)
])

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=.20,random_state =42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((531, 15), (133, 15), (531,), (133,))

# %%
x_train = transform_pipeline.fit_transform(x_train).toarray()
x_train.shape
# Out:
# (531, 56)

# %%
class LogisticRegression():
    
    def __init__(self,lr,iterations):
        
        self.lr = lr
        self.iterations = iterations
        
    def sigmoid(self,x):
        
        return 1 / (1 + np.exp(-x))
        
    def fit(self,X,Y):
        
        samples_num , features_num = X.shape
        
        self.weights = np.random.rand(features_num)
        self.bais = 1
        
        for i in range(self.iterations):
            y_pred = np.dot(X,self.weights) + self.bais
            y_pred = self.sigmoid(y_pred)
            
            error = y_pred - Y
            dW =   np.sum(X.T.dot(error)) / samples_num
            db = np.sum(error) / samples_num
            
            self.weights -=  dW * self.lr
            self.bais -=  db * self.lr
    
    def predict(self,X):
        net = np.dot(X,self.weights) + self.bais
        net = self.sigmoid(net)
        net = np.round(net)
        return net
    
    def get_accuracy(self,y_true,y_pred):
        correct= 0
        total = len(y_true)
        
        for i in range(total):
            if y_true[i] == y_pred[i]:
                correct +=1
        
        
        accuracy = correct / total
        
        return accuracy

# %%
lg = LogisticRegression(0.1,10000)

# %%
lg.fit(x_train,y_train)

# %%
y_pred = lg.predict(x_train)
print("Training Accuracy is ",lg.get_accuracy(y_train,y_pred))
# Out:
# Training Accuracy is  0.7382297551789078

# %%
if x_test.shape[1] < 40:
    x_test = transform_pipeline.transform(x_test).toarray()
    x_test.shape

# %%
y_pred = lg.predict(x_test)
print("Training Accuracy is ",lg.get_accuracy(y_test,y_pred))
# Out:
# Training Accuracy is  0.7218045112781954

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.77      0.77        81
#            1       0.64      0.65      0.65        52
#
#     accuracy                           0.72       133
#    macro avg       0.71      0.71      0.71       133
# weighted avg       0.72      0.72      0.72       133

# %%
x_train = x_train.T
x_test = x_test.T

# %%
INPUT_SHAPE = x_train.shape[0]
HIDDEN_SIZE = 50
OUTPUT = 1
LR = 0.1
epochs = 2001

# %%
# Define sigmoid activation function
def sigmoid(x):
    return 1 / ( 1 + np.exp(-x))

# Define derivative of sigmoid function
def sigmoid_derivative(x):
    return x * (1 - x)

def ReLU(Z):
    return np.maximum(Z, 0)

def ReLU_deriv(Z):
    return Z > 0

# %%
def init_params(input_shape=18, hidden_size=20, output_size=1):
    W1 = np.random.rand(hidden_size, input_shape) 
    b1 = np.random.rand(hidden_size, 1) 
    W2 = np.random.rand(output_size, hidden_size) 
    b2 = np.random.rand(output_size, 1) 
    return W1, b1, W2, b2

def forward_prop(W1, b1, W2, b2, X):
    Z1 = W1.dot(X) + b1
    A1 = ReLU(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = sigmoid(Z2)
    return Z1, A1, Z2, A2

def backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y):
    m = X.shape[1]
    dZ2 = A2 - Y
    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2,axis=1)
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)
    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1)
    
    return dW1, db1, dW2, db2
    

def update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1    
    W2 = W2 - alpha * dW2  
    b2 = b2 - alpha * db2    
    return W1, b1, W2, b2

def get_mse(y_true, y_pred):
    return (np.square(y_true - y_pred)).mean()

def get_accuracy(y_true, y_pred):
    correct = 0
    total = len(y_true)
    
    for i in range(total):
        if y_true[i] == y_pred[i]:
            correct += 1
    
    accuracy = correct / total
    
    return accuracy

def make_predictions(X, W1, b1, W2, b2):
    _, _, _, A2 = forward_prop(W1, b1, W2, b2, X)
    A2 = np.round(A2).squeeze()
    return A2

# %%
def gradient_descent(X, Y, alpha, iterations,input_shape, hidden_size, output_size):
    history = {"epoch":[],"loss":[],"accuracy":[]}
    W1, b1, W2, b2 = init_params(input_shape, hidden_size, output_size)
     
    for i in range(iterations):
        Z1, A1, Z2, A2 = forward_prop(W1, b1, W2, b2, X)        
        dW1, db1, dW2, db2 = backward_prop(Z1, A1, Z2, A2, W1, W2, X, Y)
        W1, b1, W2, b2 = update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha)
        cost = get_mse(A2,Y)
        A2 = np.round(A2).squeeze()
        accuracy = get_accuracy(Y,A2)
        history['loss'].append(cost)
        history['epoch'].append(i)
        history['accuracy'].append(accuracy)
        if i % 100 == 0:
            print("Iteration: ", i)
            print("Cost is : ",cost)
            print("Accuracy is :",accuracy)
            print('################ \n')
    return W1, b1, W2, b2,history

# %%
W1, b1, W2, b2,history = gradient_descent(x_train, y_train, LR,epochs,
                          input_shape=INPUT_SHAPE, hidden_size=HIDDEN_SIZE, output_size=OUTPUT)
# Out:
# Iteration:  0
# Cost is :  0.536723163841808
# Accuracy is : 0.4632768361581921
# ################
#
# Iteration:  100
# Cost is :  0.09885099394552264
# Accuracy is : 0.8700564971751412
# ################
#
# Iteration:  200
# Cost is :  0.0889938367793758
# Accuracy is : 0.8775894538606404
# ################
#
# Iteration:  300
# Cost is :  0.08400233554398531
# Accuracy is : 0.8813559322033898
# ################
#
# Iteration:  400
# Cost is :  0.08076424472805076
# Accuracy is : 0.8813559322033898
# ################
#
# Iteration:  500
# Cost is :  0.07833472657299323
# Accuracy is : 0.8870056497175142
# ################
#
# Iteration:  600
# Cost is :  0.07607666706879546
# Accuracy is : 0.8907721280602636
# ################
#
# Iteration:  700
# Cost is :  0.07406500394335323
# Accuracy is : 0.8926553672316384
# ################
#
# Iteration:  800
# Cost is :  0.07216664812513773
# Accuracy is : 0.8983050847457628
# ################
#
# Iteration:  900
# Cost is :  0.0702734279503902
# Accuracy is : 0.9058380414312618
# ################
#
# Iteration:  1000
# Cost is :  0.06825578124099402
# Accuracy is : 0.9058380414312618
# ################
#
# Iteration:  1100
# Cost is :  0.06629284925329569
# Accuracy is : 0.9077212806026366
# ################
#
# Iteration:  1200
# Cost is :  0.06425877817233268
# Accuracy is : 0.9077212806026366
# ################
#
# Iteration:  1300
# Cost is :  0.062403077809481566
# Accuracy is : 0.911487758945386
# ################
#
# Iteration:  1400
# Cost is :  0.06065660807540777
# Accuracy is : 0.9190207156308852
# ################
#
# Iteration:  1500
# Cost is :  0.05877583952820262
# Accuracy is : 0.9265536723163842
# ################
#
# Iteration:  1600
# Cost is :  0.05682738354341231
# Accuracy is : 0.9265536723163842
# ################
#
# Iteration:  1700
# Cost is :  0.05493800448487443
# Accuracy is : 0.9303201506591338
# ################
#
# Iteration:  1800
# Cost is :  0.053078382755710946
# Accuracy is : 0.9340866290018832
# ################
#
# Iteration:  1900
# Cost is :  0.05127973299820554
# Accuracy is : 0.9322033898305084
# ################
#
# Iteration:  2000
# Cost is :  0.04957702622470769
# Accuracy is : 0.935969868173258
# ################

# %%
y_pred = make_predictions(x_test, W1, b1, W2, b2)
print("Model Accuracy on Test data :",round(get_accuracy(y_test,y_pred) * 100))
# Out:
# Model Accuracy on Test data : 86

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88        81
#            1       0.79      0.87      0.83        52
#
#     accuracy                           0.86       133
#    macro avg       0.85      0.86      0.85       133
# weighted avg       0.86      0.86      0.86       133

# %%
def plot_graph(history,string2):
    # gets the data stored inside history by a key and plot it
#     plt.plot(history[string1],label=string1)
    plt.plot(history[string2],label=string2)
    # # A legend is an area describing the elements of the graph , in the top right of the graph
    plt.legend()
    # x axis label
    plt.xlabel('epochs')
    # y axis label
    plt.ylabel(string2)
    # title
    plt.title(string2+' vs epochs')
    plt.show

# %%
plot_graph(history,'loss')

# %%
plot_graph(history,'accuracy')
